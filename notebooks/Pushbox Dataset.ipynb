# %%
from varyingsim.datasets.fov_dataset import SmoothFovDataset

# %%
location = '/home/benevans/projects/varyingsim/data/dataset.pickle'

# %%
dataset = SmoothFovDataset(location)

# %%
dataset[0]
# Out:
# {'train_obs': array([[ 0.00000000e+00,  0.00000000e+00,  1.00000000e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.61715125e-56, -7.49624175e-23,  9.99967705e-02, ...,
#           7.64703716e-20,  2.39234640e-01, -1.26030457e-02],
#         [ 2.75925507e-23, -1.74582081e-22,  9.99920189e-02, ...,
#           6.86384566e-20,  3.82985203e-01, -2.49487649e-02],
#         ...,
#         [ 2.53945627e-01,  1.89501492e-02,  9.98922446e-02, ...,
#           4.02866090e-19,  5.99400599e-01, -3.06517412e-07],
#         [ 2.53945627e-01,  1.89501480e-02,  9.98922446e-02, ...,
#           3.85355726e-19,  5.99400599e-01, -2.99091489e-07],
#         [ 2.53945627e-01,  1.89501467e-02,  9.98922446e-02, ...,
#           3.62777413e-19,  5.99400599e-01, -2.91739924e-07]]),
#  'train_act': array([[ 0.6 , -0.05],
#         [ 0.6 , -0.05],
#         [ 0.6 , -0.05],
#         ...,
#         [ 0.6 , -0.05],
#         [ 0.6 , -0.05],
#         [ 0.6 , -0.05]]),
# ...
